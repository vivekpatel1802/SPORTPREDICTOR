# %% [markdown]
# # import Libaries & Data

# %%
import pandas as pd
data=pd.read_csv('sport_data.csv')
data
# Out:
#     Age  Height     Sex       Sport
# 0    13       3    Male      Soccer
# 1    16       4    Male      Soccer
# 2    17       4    Male      Soccer
# 3    15       5    Male  Basketball
# 4    17       6    Male  Basketball
# 5    18       5    Male  Basketball
# 6    15       3    Male      Hockey
# 7    13       3    Male      Hockey
# 8    13       4    Male      Hockey
# 9    13       3  Female      Soccer
# 10   14       3  Female      Soccer
# 11   16       4  Female      Soccer
# 12   16       5  Female  Basketball
# 13   17       4  Female  Basketball
# 14   19       6  Female  Basketball
# 15   13       3  Female      Hockey
# 16   14       4  Female      Hockey
# 17   14       3  Female      Hockey

# %%
data.shape
# Out:
# (18, 4)

# %%
data.describe()
# Out:
#              Age     Height
# count  18.000000  18.000000
# mean   15.166667   4.000000
# std     1.917412   1.028992
# min    13.000000   3.000000
# 25%    13.250000   3.000000
# 50%    15.000000   4.000000
# 75%    16.750000   4.750000
# max    19.000000   6.000000

# %% [markdown]
# # Pre-Process Data

# %%
data['Sex'].replace(['Female','Male'],[0,1],inplace=True)

# %%
data.head()
# Out:
#    Age  Height  Sex       Sport
# 0   13       3    1      Soccer
# 1   16       4    1      Soccer
# 2   17       4    1      Soccer
# 3   15       5    1  Basketball
# 4   17       6    1  Basketball

# %%
data.tail()
# Out:
#     Age  Height  Sex       Sport
# 13   17       4    0  Basketball
# 14   19       6    0  Basketball
# 15   13       3    0      Hockey
# 16   14       4    0      Hockey
# 17   14       3    0      Hockey

# %% [markdown]
# # import Machine Learning Libraries

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
x=data.drop(columns='Sport')

# %%
x.head()
# Out:
#    Age  Height  Sex
# 0   13       3    1
# 1   16       4    1
# 2   17       4    1
# 3   15       5    1
# 4   17       6    1

# %%
y=data.drop(columns=['Age','Height','Sex'])

# %%
y.head()
# Out:
#         Sport
# 0      Soccer
# 1      Soccer
# 2      Soccer
# 3  Basketball
# 4  Basketball

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %% [markdown]
# # Build Machine Learning Model

# %%
clf =DecisionTreeClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Test ML MODEL

# %%
test=clf.predict(x_test)
test
# Out:
# array(['Basketball', 'Basketball', 'Basketball', 'Soccer', 'Soccer',
#        'Basketball'], dtype=object)

# %%
y_test
# Out:
#          Sport
# 5   Basketball
# 16      Hockey
# 11      Soccer
# 7       Hockey
# 8       Hockey
# 3   Basketball

# %% [markdown]
# # chack for Efficacy

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy=accuracy_score(y_test,test)
accuracy
# Out:
# 0.3333333333333333

# %%
new_student=clf.predict([[15,4,1]])
new_student
# Out:
# C:\Users\BAPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Soccer'], dtype=object)

# %% [markdown]
# # SAVE MODEL

# %%
import joblib

# %%
joblib.dump(clf,'ml_sport_model.joblib')
# Out:
# ['ml_sport_model.joblib']

# %%
c_matrix=confusion_matrix(y_test,test)
c_matrix
# Out:
# array([[2, 0, 0],
#        [1, 0, 2],
#        [1, 0, 0]], dtype=int64)

# %%
y_test
# Out:
#          Sport
# 5   Basketball
# 16      Hockey
# 11      Soccer
# 7       Hockey
# 8       Hockey
# 3   Basketball

# %%
print(classification_report(y_test,test))
# Out:
#               precision    recall  f1-score   support
#
#   Basketball       0.50      1.00      0.67         2
#       Hockey       0.00      0.00      0.00         3
#       Soccer       0.00      0.00      0.00         1
#
#     accuracy                           0.33         6
#    macro avg       0.17      0.33      0.22         6
# weighted avg       0.17      0.33      0.22         6
# C:\Users\BAPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\BAPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\BAPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
